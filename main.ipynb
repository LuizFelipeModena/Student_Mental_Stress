# %%
import config
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Student_Mental_Stress_and_Coping_Mechanisms.csv')

df.head()
# Out:
#     Student ID  Age  Gender  Academic Performance (GPA)  Study Hours Per Week  \
# 0  802-17-3671   22  Female                           2                     9
# 1  871-12-8572   25  Female                           0                    28
# 2  495-13-2672   24  Female                           0                    45
# 3  365-77-2496   20    Male                           2                     8
# 4  664-76-5622   28    Male                           0                    14
#
#    Social Media Usage (Hours per day)  Sleep Duration (Hours per night)  \
# 0                                   2                                12
# 1                                   0                                 6
# 2                                   3                                12
# 3                                   7                                 7
# 4                                   6                                 8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Student ID                          760 non-null    object
#  1   Age                                 760 non-null    int64
#  2   Gender                              760 non-null    object
#  3   Academic Performance (GPA)          760 non-null    int64
#  4   Study Hours Per Week                760 non-null    int64
#  5   Social Media Usage (Hours per day)  760 non-null    int64
#  6   Sleep Duration (Hours per night)    760 non-null    int64
#  7   Physical Exercise (Hours per week)  760 non-null    int64
#  8   Family Support                      760 non-null    int64
#  9   Financial Stress                    760 non-null    int64
#  10  Peer Pressure                       760 non-null    int64
# ...

# %% [markdown]
# Descrição das colunas:
#
# - Student ID: Código ID dos alunos.
#
# - Age: Idade do estudante (entre 18 e 30 anos).
#
# - Gender: Male, Female, Non-binary, Prefer not to say
#
# - Academic Performance: Média de notas do aluno (De 0.0 a 4.0).
#
# - Study Hours Per Week: Tempo de estudos por semana (De 0 a 60 horas).
#
# - Social Media Usage: Média de horas por dia que o aluno usa rede social.
#
# - Sleep Duration: Tempo de sono do aluno por noite em horas.
#
# - Physical Exercise: Tempo médio de exercício físico que o estudante pratica por semana em horas.
#
# - Family Support: Autorrelato do nível de suporte da família (1 = pouco suporte, 5 = muito suporte).
#
# - Financial Stress: Autorrelato do estresse financeiro (1 = sem estresse, 5 = muito estresse).
#
# - Peer Pressure: Autorrelato das pressão causada por colegas (1 = pouca pressão, 5 = muita pressão).
#
# - Relationship Stress: Autorrelato do nível de estresse em relacionamento (1 = pouco estresse, 5 = muito estresse).
#
# - Mental Stress Level: Autorrelato do nível de estresse mental (1 = sem estresse, 10 = estresse extremo).
#
# - Counseling Attendance: Se o aluno passou por aconselhamento (0 = No, 1 = Yes).
#
# - Diet Quality: Autorrelato da qualidade da dieta (1 = dieta ruim, 5 = dieta excelente).
#
# - Stress Coping Mechanisms: Estretagéia que o aluno usa para alívio de estresse, incluindo: Talking to Family, Reading, Yoga, Exercise, Meditation, And many more…
#
# - Cognitive Distortions: Autorrelato do nível de distorção cognitiva (1 = sem distorções, 5 = distorções severas).
#
# - Family Mental Health History: Se o estudante te histórico de problemas mentais na família (0 = No, 1 = Yes).
#
# - Medical Condition: Se o aluno tem alguma condição mental pré-existente que possa afetar sua saúde mental (0 = No, 1 = Yes).
#
# - Substance Use: Autorrelato do nível de uso de substâncias (1 = não faz uso, 5 = faz uso pesado).

# %%
df.drop(columns='Student ID', inplace= True)

# %%
df = config.normalize_dataframe_columns(df)

df.head()
# Out:
#    age  gender  academic_performance  study_hours_per_week  \
# 0   22  Female                     2                     9
# 1   25  Female                     0                    28
# 2   24  Female                     0                    45
# 3   20    Male                     2                     8
# 4   28    Male                     0                    14
#
#    social_media_usage  sleep_duration  physical_exercise  family_support  \
# 0                   2              12                  2               1
# 1                   0               6                  0               1
# 2                   3              12                 10               3
# 3                   7               7                  4               1
# 4                   6               8                  1               2
#
#    financial_stress  peer_pressure  relationship_stress  mental_stress_level  \
# 0                 1              3                    5                    9
# ...

# %%
columns = {'counseling_attendance', 'family_mental_health_history', 'medical_condition'}

df = config.convert_to_binary(df, columns)

df.head()
# Out:
#    age  gender  academic_performance  study_hours_per_week  \
# 0   22  Female                     2                     9
# 1   25  Female                     0                    28
# 2   24  Female                     0                    45
# 3   20    Male                     2                     8
# 4   28    Male                     0                    14
#
#    social_media_usage  sleep_duration  physical_exercise  family_support  \
# 0                   2              12                  2               1
# 1                   0               6                  0               1
# 2                   3              12                 10               3
# 3                   7               7                  4               1
# 4                   6               8                  1               2
#
#    financial_stress  peer_pressure  relationship_stress  mental_stress_level  \
# 0                 1              3                    5                    9
# ...

# %%
df_corr = df.drop(columns= ['gender', 'stress_coping_mechanisms'])
df_corr

plt.figure(figsize=(12,6))

mask = np.tril(np.ones_like(df_corr.corr(), dtype=bool))
sns.heatmap(df_corr.corr(), mask=mask, fmt='.2f', annot=True)

plt.show()

# %%
sns.barplot(df, x='academic_performance', y='study_hours_per_week');

# %%
sns.jointplot(df, x='academic_performance', y='study_hours_per_week', kind="hex", color="#4CB391")

# %%
df.groupby('academic_performance')['study_hours_per_week'].mean()
# Out:
# academic_performance
# 0    29.857143
# 1    28.664234
# 2    28.724832
# 3    28.241176
# 4    30.237762
# Name: study_hours_per_week, dtype: float64
